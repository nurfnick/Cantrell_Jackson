# %% [markdown]
# <a href="https://colab.research.google.com/github/nurfnick/Cantrell_Jackson/blob/master/Tracy's%20hot%20mess%20of%20code1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pa
import numpy as np
import datetime as dt
from datetime import date as date
import time

# %% [markdown]
# # trucks want unique id (id is unique for each truck) want to grab the customer and the date used
# #tickets based on job details, multiple tickets/ invoice per and mults 'special projects' different categories etc.
# #for each unique ticket and invoice, the type and number of job type of each customer.

# %%
url1 = 'https://raw.githubusercontent.com/nurfnick/Cantrell_Jackson/master/hs_customer_4.csv'
df1 = pa.read_csv(url1)
df1
# Out:
#         invoice_id  hs_customer  ...  ticket_item_type  details
# 0           179988            4  ...   job_description   1281.0
# 1           179987            4  ...   job_description   1281.0
# 2           179995            4  ...   job_description   1281.0
# 3           179978            4  ...   job_description   1281.0
# 4           180011            4  ...   job_description   1281.0
# ...            ...          ...  ...               ...      ...
# 187563      223637            4  ...   job_description      NaN
# 187564      223548            4  ...   job_description      NaN
# 187565      223544            4  ...   job_description      NaN
# 187566      223547            4  ...   job_description      NaN
# 187567      223546            4  ...   job_description      NaN
#
# [187568 rows x 9 columns]

# %%
df1
# Out:
#         invoice_id  hs_customer  ...  ticket_item_type  details
# 0           179988            4  ...   job_description   1281.0
# 1           179987            4  ...   job_description   1281.0
# 2           179995            4  ...   job_description   1281.0
# 3           179978            4  ...   job_description   1281.0
# 4           180011            4  ...   job_description   1281.0
# ...            ...          ...  ...               ...      ...
# 187563      223637            4  ...   job_description      NaN
# 187564      223548            4  ...   job_description      NaN
# 187565      223544            4  ...   job_description      NaN
# 187566      223547            4  ...   job_description      NaN
# 187567      223546            4  ...   job_description      NaN
#
# [187568 rows x 9 columns]

# %%
del i
del x
del j
del readable

# %%
for i in df1['ticket_date']:
  readable = dt.datetime.fromtimestamp(i).strftime('%m%y')
  df1['readable'] = readable
print(df1)
# its only printing 187568 roes but all of the 'readable are the same.
# Out:
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      0119
# 1           179987            4  ...   1281.0      0119
# 2           179995            4  ...   1281.0      0119
# 3           179978            4  ...   1281.0      0119
# 4           180011            4  ...   1281.0      0119
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      0119
# 187564      223548            4  ...      NaN      0119
# 187565      223544            4  ...      NaN      0119
# 187566      223547            4  ...      NaN      0119
# 187567      223546            4  ...      NaN      0119
#
# [187568 rows x 10 columns]

# %%
for i in df1['ticket_date']:
  readable = dt.datetime.fromtimestamp(i).strftime('%m%y')
  df1['readable'] = readable
  print(df1)
# its printing all of them multiple times each 187568 has one corresponding i.
# Out:
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      0918
# 1           179987            4  ...   1281.0      0918
# 2           179995            4  ...   1281.0      0918
# 3           179978            4  ...   1281.0      0918
# 4           180011            4  ...   1281.0      0918
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      0918
# 187564      223548            4  ...      NaN      0918
# 187565      223544            4  ...      NaN      0918
# 187566      223547            4  ...      NaN      0918
# 187567      223546            4  ...      NaN      0918
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      0918
# 1           179987            4  ...   1281.0      0918
# 2           179995            4  ...   1281.0      0918
# 3           179978            4  ...   1281.0      0918
# 4           180011            4  ...   1281.0      0918
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      0918
# 187564      223548            4  ...      NaN      0918
# 187565      223544            4  ...      NaN      0918
# 187566      223547            4  ...      NaN      0918
# 187567      223546            4  ...      NaN      0918
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      0918
# 1           179987            4  ...   1281.0      0918
# 2           179995            4  ...   1281.0      0918
# 3           179978            4  ...   1281.0      0918
# 4           180011            4  ...   1281.0      0918
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      0918
# 187564      223548            4  ...      NaN      0918
# 187565      223544            4  ...      NaN      0918
# 187566      223547            4  ...      NaN      0918
# 187567      223546            4  ...      NaN      0918
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      0918
# 1           179987            4  ...   1281.0      0918
# 2           179995            4  ...   1281.0      0918
# 3           179978            4  ...   1281.0      0918
# 4           180011            4  ...   1281.0      0918
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      0918
# 187564      223548            4  ...      NaN      0918
# 187565      223544            4  ...      NaN      0918
# 187566      223547            4  ...      NaN      0918
# 187567      223546            4  ...      NaN      0918
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1018
# 187564      223548            4  ...      NaN      1018
# 187565      223544            4  ...      NaN      1018
# 187566      223547            4  ...      NaN      1018
# 187567      223546            4  ...      NaN      1018
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1018
# 1           179987            4  ...   1281.0      1018
# 2           179995            4  ...   1281.0      1018
# 3           179978            4  ...   1281.0      1018
# 4           180011            4  ...   1281.0      1018
# ...            ...          ...  ...      ...       ...
# ...
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1218
# 187564      223548            4  ...      NaN      1218
# 187565      223544            4  ...      NaN      1218
# 187566      223547            4  ...      NaN      1218
# 187567      223546            4  ...      NaN      1218
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1218
# 1           179987            4  ...   1281.0      1218
# 2           179995            4  ...   1281.0      1218
# 3           179978            4  ...   1281.0      1218
# 4           180011            4  ...   1281.0      1218
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1218
# 187564      223548            4  ...      NaN      1218
# 187565      223544            4  ...      NaN      1218
# 187566      223547            4  ...      NaN      1218
# 187567      223546            4  ...      NaN      1218
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1218
# 1           179987            4  ...   1281.0      1218
# 2           179995            4  ...   1281.0      1218
# 3           179978            4  ...   1281.0      1218
# 4           180011            4  ...   1281.0      1218
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1218
# 187564      223548            4  ...      NaN      1218
# 187565      223544            4  ...      NaN      1218
# 187566      223547            4  ...      NaN      1218
# 187567      223546            4  ...      NaN      1218
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1218
# 1           179987            4  ...   1281.0      1218
# 2           179995            4  ...   1281.0      1218
# 3           179978            4  ...   1281.0      1218
# 4           180011            4  ...   1281.0      1218
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1218
# 187564      223548            4  ...      NaN      1218
# 187565      223544            4  ...      NaN      1218
# 187566      223547            4  ...      NaN      1218
# 187567      223546            4  ...      NaN      1218
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1218
# 1           179987            4  ...   1281.0      1218
# 2           179995            4  ...   1281.0      1218
# 3           179978            4  ...   1281.0      1218
# 4           180011            4  ...   1281.0      1218
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1218
# 187564      223548            4  ...      NaN      1218
# 187565      223544            4  ...      NaN      1218
# 187566      223547            4  ...      NaN      1218
# 187567      223546            4  ...      NaN      1218
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1218
# 1           179987            4  ...   1281.0      1218
# 2           179995            4  ...   1281.0      1218
# 3           179978            4  ...   1281.0      1218
# 4           180011            4  ...   1281.0      1218
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1218
# 187564      223548            4  ...      NaN      1218
# 187565      223544            4  ...      NaN      1218
# 187566      223547            4  ...      NaN      1218
# 187567      223546            4  ...      NaN      1218
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1218
# 1           179987            4  ...   1281.0      1218
# 2           179995            4  ...   1281.0      1218
# 3           179978            4  ...   1281.0      1218
# 4           180011            4  ...   1281.0      1218
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1218
# 187564      223548            4  ...      NaN      1218
# 187565      223544            4  ...      NaN      1218
# 187566      223547            4  ...      NaN      1218
# 187567      223546            4  ...      NaN      1218
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1218
# 1           179987            4  ...   1281.0      1218
# 2           179995            4  ...   1281.0      1218
# 3           179978            4  ...   1281.0      1218
# 4           180011            4  ...   1281.0      1218
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1218
# 187564      223548            4  ...      NaN      1218
# 187565      223544            4  ...      NaN      1218
# 187566      223547            4  ...      NaN      1218
# 187567      223546            4  ...      NaN      1218
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1218
# 1           179987            4  ...   1281.0      1218
# 2           179995            4  ...   1281.0      1218
# 3           179978            4  ...   1281.0      1218
# 4           180011            4  ...   1281.0      1218
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1218
# 187564      223548            4  ...      NaN      1218
# 187565      223544            4  ...      NaN      1218
# 187566      223547            4  ...      NaN      1218
# 187567      223546            4  ...      NaN      1218
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1218
# 1           179987            4  ...   1281.0      1218
# 2           179995            4  ...   1281.0      1218
# 3           179978            4  ...   1281.0      1218
# 4           180011            4  ...   1281.0      1218
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1218
# 187564      223548            4  ...      NaN      1218
# 187565      223544            4  ...      NaN      1218
# 187566      223547            4  ...      NaN      1218
# 187567      223546            4  ...      NaN      1218
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1218
# 1           179987            4  ...   1281.0      1218
# 2           179995            4  ...   1281.0      1218
# 3           179978            4  ...   1281.0      1218
# 4           180011            4  ...   1281.0      1218
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1218
# 187564      223548            4  ...      NaN      1218
# 187565      223544            4  ...      NaN      1218
# 187566      223547            4  ...      NaN      1218
# 187567      223546            4  ...      NaN      1218
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1218
# 1           179987            4  ...   1281.0      1218
# 2           179995            4  ...   1281.0      1218
# 3           179978            4  ...   1281.0      1218
# 4           180011            4  ...   1281.0      1218
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1218
# 187564      223548            4  ...      NaN      1218
# 187565      223544            4  ...      NaN      1218
# 187566      223547            4  ...      NaN      1218
# 187567      223546            4  ...      NaN      1218
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1218
# 1           179987            4  ...   1281.0      1218
# 2           179995            4  ...   1281.0      1218
# 3           179978            4  ...   1281.0      1218
# 4           180011            4  ...   1281.0      1218
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1218
# 187564      223548            4  ...      NaN      1218
# 187565      223544            4  ...      NaN      1218
# 187566      223547            4  ...      NaN      1218
# 187567      223546            4  ...      NaN      1218
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1218
# 1           179987            4  ...   1281.0      1218
# 2           179995            4  ...   1281.0      1218
# 3           179978            4  ...   1281.0      1218
# 4           180011            4  ...   1281.0      1218
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1218
# 187564      223548            4  ...      NaN      1218
# 187565      223544            4  ...      NaN      1218
# 187566      223547            4  ...      NaN      1218
# 187567      223546            4  ...      NaN      1218
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1218
# 1           179987            4  ...   1281.0      1218
# 2           179995            4  ...   1281.0      1218
# 3           179978            4  ...   1281.0      1218
# 4           180011            4  ...   1281.0      1218
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1218
# 187564      223548            4  ...      NaN      1218
# 187565      223544            4  ...      NaN      1218
# 187566      223547            4  ...      NaN      1218
# 187567      223546            4  ...      NaN      1218
#
# [187568 rows x 10 columns]
#         invoice_id  hs_customer  ...  details  readable
# 0           179988            4  ...   1281.0      1218
# 1           179987            4  ...   1281.0      1218
# 2           179995            4  ...   1281.0      1218
# 3           179978            4  ...   1281.0      1218
# 4           180011            4  ...   1281.0      1218
# ...            ...          ...  ...      ...       ...
# 187563      223637            4  ...      NaN      1218
# 187564      223548            4  ...      NaN      1218
# 187565      223544            4  ...      NaN      1218
# 187566      223547            4  ...      NaN      1218
# 187567      223546            4  ...      NaN      1218
#
# [187568 rows x 10 columns]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-209-39f236ded01f> in <module>()
#       2   readable = dt.datetime.fromtimestamp(i).strftime('%m%y')
#       3   df1['readable'] = readable
# ----> 4   print(df1)
#       5 # its printing all of them multiple times
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __repr__(self)
#     653             max_cols=max_cols,
#     654             line_width=width,
# --> 655             show_dimensions=show_dimensions,
#     656         )
#     657
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, min_rows, max_cols, show_dimensions, decimal, line_width)
#     772             show_dimensions=show_dimensions,
#     773             decimal=decimal,
# --> 774             line_width=line_width,
#     775         )
#     776         formatter.to_string()
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/formats/format.py in __init__(self, frame, buf, columns, col_space, header, index, na_rep, formatters, justify, float_format, sparsify, index_names, line_width, max_rows, min_rows, max_cols, show_dimensions, decimal, table_id, render_links, **kwds)
#     500             self.columns = frame.columns
#     501
# --> 502         self._chk_truncate()
#     503         self.adj = _get_adjustment()
#     504
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/formats/format.py in _chk_truncate(self)
#     569             else:
#     570                 row_num = max_rows_adj // 2
# --> 571                 frame = concat((frame.iloc[:row_num, :], frame.iloc[-row_num:, :]))
#     572             self.tr_row_num = row_num
#     573         else:
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     256     )
#     257
# --> 258     return op.get_result()
#     259
#     260
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/reshape/concat.py in get_result(self)
#     471
#     472             new_data = concatenate_block_managers(
# --> 473                 mgrs_indexers, self.new_axes, concat_axis=self.axis, copy=self.copy
#     474             )
#     475             if not self.copy:
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/managers.py in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#    2046                 values = values.view()
#    2047             b = b.make_block_same_class(values, placement=placement)
# -> 2048         elif is_uniform_join_units(join_units):
#    2049             b = join_units[0].block.concat_same_type(
#    2050                 [ju.block for ju in join_units], placement=placement
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/concat.py in is_uniform_join_units(join_units)
#     390         # no blocks that would get missing values (can lead to type upcasts)
#     391         # unless we're an extension dtype.
# --> 392         all(not ju.is_na or ju.block.is_extension for ju in join_units)
#     393         and
#     394         # no blocks with indexers (as then the dimensions do not fit)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/concat.py in <genexpr>(.0)
#     390         # no blocks that would get missing values (can lead to type upcasts)
#     391         # unless we're an extension dtype.
# --> 392         all(not ju.is_na or ju.block.is_extension for ju in join_units)
#     393         and
#     394         # no blocks with indexers (as then the dimensions do not fit)
#
# pandas/_libs/properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/concat.py in is_na(self)
#     170         chunk_len = max(total_len // 40, 1000)
#     171         for i in range(0, total_len, chunk_len):
# --> 172             if not isna(values_flat[i : i + chunk_len]).all():
#     173                 return False
#     174
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/dtypes/missing.py in isna(obj)
#     120     Name: 1, dtype: bool
#     121     """
# --> 122     return _isna(obj)
#     123
#     124
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/dtypes/missing.py in _isna_new(obj)
#     145         ),
#     146     ):
# --> 147         return _isna_ndarraylike(obj)
#     148     elif isinstance(obj, ABCGeneric):
#     149         return obj._constructor(obj._data.isna(func=isna))
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/dtypes/missing.py in _isna_ndarraylike(obj)
#     218
#     219 def _isna_ndarraylike(obj):
# --> 220     is_extension = is_extension_array_dtype(obj)
#     221
#     222     if not is_extension:
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/dtypes/common.py in is_extension_array_dtype(arr_or_dtype)
#    1787     """
#    1788     dtype = getattr(arr_or_dtype, "dtype", arr_or_dtype)
# -> 1789     return isinstance(dtype, ExtensionDtype) or registry.find(dtype) is not None
#    1790
#    1791
#
# KeyboardInterrupt:

# %%
for i in df1['ticket_date']:
  i = []
  x = []
  for i in readable:
    i = x
    readable = []
    readable = dt.datetime.fromtimestamp(x).strftime('%m%y')
print(len(readable))
# Out:
# 0

# %%
#16, 18, 19, 5 are too big- zipped files.
#34,39,41,45 too big
# for customers 4 10 15 28
custnums = [4]
for n in range(len(custnums)):
  print('Customer '+str(custnums[n])+':')
  #read files
  url = 'https://raw.githubusercontent.com/nurfnick/Cantrell_Jackson/master/hs_customer_'+str(custnums[n])+'.csv'
  df = pa.read_csv(url)
  #make date a number, make blanks = 0, readable upper/lower case, get rid of duplicates
  for i in df['ticket_date']:
    readable
    readable = dt.datetime.fromtimestamp(i).strftime('%m%y')
    df['readable'] = readable
  values = {'invoice_id': 0, 'hs_customer': 0, 'invoice_total': 0, 'invoice_time': 0, 'ticket_id': 0, 'job_type': 0, 'ticket_date': 0,'ticket_item_type': 0, 'details': 0}
  df.fillna(value=values)
  dfnoNAN = df.fillna(value=values)
  dfnoduplicates = dfnoNAN.drop_duplicates()
  dfnoduplicates.columns = dfnoduplicates.columns.str.lower()
  #group by ticket date
  dfgroupdates = dfnoduplicates.groupby('readable')
  #grab one of the dates
  
  billdates = dfgroupdates.get_group('')
  #group by the job type
  billdatesjobtype = billdates.groupby('job_type')
  billdatessp = billdatesjobtype.get_group('Special Projects')
  customerdatessplen = len(billdatessp)
  customerdatesspmoney = round(sum(billdatessp['invoice_total']),2)
  if 'Water Hauling' in billdatesjobtype.groups.keys():
    billdateswh = billdatesjobtype.get_group('Water Hauling')
    customerdateswhlen = len(billdateswh)
    customerdateswhmoney = round(sum(billdateswh['invoice_total']),2)
  else:
    customerdateswhlen = 0
    customerdateswhmoney = 0
  if 'Flowback' in billdatesjobtype.groups.keys():
    billdatesfb = billdatesjobtype.get_group('Flowback')
    customerdatesfblen = len(billdatesfb)
    customerdatesfbmoney = round(sum(billdatesfb['invoice_total']),2)
    customerdateslentot = customerdatessplen + customerdatesfblen + customerdateswhlen
    customerdatesmoneytot = customerdatesspmoney + customerdatesfbmoney + customerdateswhmoney
    print(f'Bill date Summary:\n Special Projects Tickets Count: {customerdatessplen:,.0f}\n Cash: ${customerdatsspmoney:,.2f}\n Water Hauling Ticket Count: {customerdateswhlen:,.0f}\n Cash: ${customerdateswhmoney:,.2f}\n Flowback Ticket Count: {customerdatesfblen:,.0f}\n Cash: ${customerdatesfbmoney:,.2f}\n Total Customer Ticket Count: {customerdateslentot:,.0f}\n Cash: ${customerdatesmoneytot:,.2f}')
  else:
    customerdateslentot = customerdatessplen + customerdateswhlen
    customerdatesmoneytot = customerdatesspmoney + customerdateswhmoney
    print(f'Bill date Summary:\n Special Projects Tickets Count: {customerdatessplen:,.0f}\n Cash: ${customerdatesspmoney:,.2f}\n Water Hauling Ticket Count: {customerdateswhlen:,.0f}\n Cash: ${customerdateswhmoney:,.2f}\n No Flowback tickets\n Total Customer Ticket Count: {customerdateslentot:,.0f}\n Cash: ${customerdatesmoneytot:,.2f}')
  print('\n')
# Out:
#   File "<ipython-input-8-21eec83a9b6b>", line 19
#     '01-18' = 'jan2018'
#     ^
# SyntaxError: can't assign to literal
