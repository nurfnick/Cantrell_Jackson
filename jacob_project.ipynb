# %% [markdown]
# <a href="https://colab.research.google.com/github/nurfnick/Cantrell_Jackson/blob/master/jacob_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pa
import numpy as np

# %%
url = 'https://raw.githubusercontent.com/nurfnick/Cantrell_Jackson/master/Support-Oct18-Sept19.csv'

# %%
df = pa.read_csv(url)
pa.set_option('display.max_rows', df2.shape[0]+1)

# %%
df
# Out:
#      Ticket ID  HS Customer  ... Agent interactions Customer interactions
# 0           35           18  ...                  1                     1
# 1           36           19  ...                  2                     1
# 2           44           20  ...                  1                     1
# 3           54           20  ...                  1                     1
# 4           55           23  ...                  1                     1
# 5           65           18  ...                  1                     1
# 6           71           18  ...                  0                     1
# 7           73           18  ...                  1                     1
# 8           75           18  ...                  1                     1
# 9           76           18  ...                  2                     1
# 10          82           15  ...                  0                     1
# 11          84           18  ...                  0                     1
# ...

# %%
df2 =df[df['Weight']==3]
df3 =df[df['Weight']==2]
df4 =df[df['Weight']==1]
df5 =df[df['Weight']==4]
df6 =df[df['Weight']==5]
df7 =df[df['Weight']==6]

# %%
cust1=df2[df2['HS Customer']==1]
cust2=df2[df2['HS Customer']==2]
cust3=df2[df2['HS Customer']==3]
cust4=df2[df2['HS Customer']==4]
cust5=df2[df2['HS Customer']==5]
cust6=df2[df2['HS Customer']==6]
cust7=df2[df2['HS Customer']==7]
cust8=df2[df2['HS Customer']==8]
cust9=df2[df2['HS Customer']==9]
cust10=df2[df2['HS Customer']==10]
cust11=df2[df2['HS Customer']==11]
cust12=df2[df2['HS Customer']==12]
cust13=df2[df2['HS Customer']==13]
cust14=df2[df2['HS Customer']==14]
cust15=df2[df2['HS Customer']==15]
cust16=df2[df2['HS Customer']==16]
cust17=df2[df2['HS Customer']==17]
cust18=df2[df2['HS Customer']==18]
cust19=df2[df2['HS Customer']==19]
cust20=df2[df2['HS Customer']==20]

# %%
for x in range(0,100):
    print(
    "cust'{x}'=df2[df2['HS Customer']=='{x}']"
# Out:
#   File "<ipython-input-109-e6b07d29a088>", line 3
#     "cust'{x}'=df2[df2['HS Customer']=='{x}']"
#                                                ^
# SyntaxError: unexpected EOF while parsing

# %%
Total = sum(cust1['Customer interactions'])
print (Total)
Total = sum(cust2['Customer interactions'])
print (Total)
Total = sum(cust3['Customer interactions'])
print (Total)
Total = sum(cust4['Customer interactions'])
print (Total)
Total = sum(cust5['Customer interactions'])
print (Total)
Total = sum(cust6['Customer interactions'])
print (Total)
Total = sum(cust7['Customer interactions'])
print (Total)
Total = sum(cust8['Customer interactions'])
print (Total)
Total = sum(cust9['Customer interactions'])
print (Total)
Total = sum(cust10['Customer interactions'])
print (Total)
Total = sum(cust11['Customer interactions'])
print (Total)
Total = sum(cust12['Customer interactions'])
print (Total)
Total = sum(cust13['Customer interactions'])
print (Total)
Total = sum(cust14['Customer interactions'])
print (Total)
Total = sum(cust15['Customer interactions'])
print (Total)
Total = sum(cust16['Customer interactions'])
print (Total)
Total = sum(cust17['Customer interactions'])
print (Total)
Total = sum(cust18['Customer interactions'])
print (Total)
Total = sum(cust19['Customer interactions'])
print (Total)
Total = sum(cust20['Customer interactions'])
print (Total)
# Out:
# 0
# 0
# 0
# 1
# 2
# 0
# 0
# 0
# 0
# 3
# 0
# 0
# 0
# 0
# 11
# 4
# 0
# 38
# 6
# 31

# %%
Total = sum(df2['Agent interactions'])
print (Total)
Total = sum(df2['Customer interactions'])
print (Total)
Total = sum(df3['Agent interactions'])
print (Total)
Total = sum(df3['Customer interactions'])
print (Total)
Total = sum(df4['Agent interactions'])
print (Total)
Total = sum(df4['Customer interactions'])
print (Total)
Total = sum(df5['Agent interactions'])
print (Total)
Total = sum(df5['Customer interactions'])
print (Total)
Total = sum(df6['Agent interactions'])
print (Total)
Total = sum(df6['Customer interactions'])
print (Total)
Total = sum(df7['Agent interactions'])
print (Total)
Total = sum(df7['Customer interactions'])
print (Total)
# Out:
# 92
# 151
# 73
# 98
# 18
# 34
# 110
# 163
# 33
# 43
# 0
# 0

# %%
df2
# Out:
#      Ticket ID  HS Customer  ... Agent interactions Customer interactions
# 0           35           18  ...                  1                     1
# 9           76           18  ...                  2                     1
# 13          87           18  ...                  0                     1
# 17         101           18  ...                  0                     2
# 22         106           21  ...                  1                     1
# 23         107            4  ...                  4                     1
# 24         111           20  ...                  0                     6
# 25         112           18  ...                  2                     1
# 32         129           15  ...                  3                     3
# 38         141            5  ...                  0                     1
# 45         151           19  ...                  1                     1
# 46         152           16  ...                  2                     2
# ...

# %%
Weight2 =df[df['Weight']==2]

# %%
Weight2
# Out:
#      Ticket ID  HS Customer  ... Agent interactions Customer interactions
# 1           36           19  ...                  2                     1
# 4           55           23  ...                  1                     1
# 5           65           18  ...                  1                     1
# 6           71           18  ...                  0                     1
# 10          82           15  ...                  0                     1
# 14          89           15  ...                  1                     1
# 15          92           15  ...                  2                     2
# 16          97           20  ...                  1                     1
# 18         102            5  ...                  1                     1
# 20         104            4  ...                  0                     1
# 26         114           18  ...                  1                     1
# 27         115           28  ...                  1                     1
# ...

# %%
Weight1=df[df['Weight']==1]

# %%
Weight1
# Out:
#      Ticket ID  HS Customer  ... Agent interactions Customer interactions
# 2           44           20  ...                  1                     1
# 3           54           20  ...                  1                     1
# 7           73           18  ...                  1                     1
# 8           75           18  ...                  1                     1
# 19         103           15  ...                  3                     4
# 35         134           15  ...                  0                     1
# 63         175           10  ...                  1                     2
# 74         194           18  ...                  0                     1
# 81         206           39  ...                  1                     2
# 96         325           28  ...                  2                     3
# 97         327           18  ...                  0                     1
# 98         328           18  ...                  1                     1
# ...
