# %% [markdown]
# <a href="https://colab.research.google.com/github/nurfnick/Cantrell_Jackson/blob/master/jacob_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pa
import numpy as np

# %%
url = 'https://raw.githubusercontent.com/nurfnick/Cantrell_Jackson/master/Support-Oct18-Sept19.csv'

# %%
df2 = pa.read_csv(url)
pa.set_option('display.max_rows', df2.shape[0]+1)
print(df2)
# Out:
#      Ticket ID  HS Customer  ... Agent interactions Customer interactions
# 0           35           18  ...                  1                     1
# 1           36           19  ...                  2                     1
# 2           44           20  ...                  1                     1
# 3           54           20  ...                  1                     1
# 4           55           23  ...                  1                     1
# 5           65           18  ...                  1                     1
# 6           71           18  ...                  0                     1
# 7           73           18  ...                  1                     1
# 8           75           18  ...                  1                     1
# 9           76           18  ...                  2                     1
# 10          82           15  ...                  0                     1
# 11          84           18  ...                  0                     1
# ...

# %%
df2
# Out:
#      Ticket ID  HS Customer  ... Agent interactions Customer interactions
# 0           35           18  ...                  1                     1
# 1           36           19  ...                  2                     1
# 2           44           20  ...                  1                     1
# 3           54           20  ...                  1                     1
# 4           55           23  ...                  1                     1
# ..         ...          ...  ...                ...                   ...
# 279       1009           18  ...                  1                     1
# 280       1012           18  ...                  1                     3
# 281       1014           18  ...                  2                     3
# 282       1016           18  ...                  1                     2
# 283       1017           18  ...                  0                     3
#
# [284 rows x 13 columns]

# %%
Weight =df2[df2['Weight']==3]

# %%
Weight
# Out:
#      Ticket ID  HS Customer  ... Agent interactions Customer interactions
# 0           35           18  ...                  1                     1
# 9           76           18  ...                  2                     1
# 13          87           18  ...                  0                     1
# 17         101           18  ...                  0                     2
# 22         106           21  ...                  1                     1
# ..         ...          ...  ...                ...                   ...
# 273        999           18  ...                  0                     2
# 274       1000           18  ...                  1                     1
# 277       1007           25  ...                  2                     2
# 278       1008           18  ...                  1                     2
# 282       1016           18  ...                  1                     2
#
# [82 rows x 13 columns]

# %%
Weight2 =df2[df2['Weight']==2]

# %%
Weight2
# Out:
#      Ticket ID  HS Customer  ... Agent interactions Customer interactions
# 1           36           19  ...                  2                     1
# 4           55           23  ...                  1                     1
# 5           65           18  ...                  1                     1
# 6           71           18  ...                  0                     1
# 10          82           15  ...                  0                     1
# ..         ...          ...  ...                ...                   ...
# 249        951           18  ...                  2                     1
# 259        963            5  ...                  0                     1
# 265        979           15  ...                  1                     2
# 270        994           26  ...                  1                     1
# 272        997           10  ...                  1                     1
#
# [70 rows x 13 columns]

# %%
Weight1 =df2[df2['Weight']==1]

# %%
Weight1
# Out:
#      Ticket ID  HS Customer  ... Agent interactions Customer interactions
# 2           44           20  ...                  1                     1
# 3           54           20  ...                  1                     1
# 7           73           18  ...                  1                     1
# 8           75           18  ...                  1                     1
# 19         103           15  ...                  3                     4
# 35         134           15  ...                  0                     1
# 63         175           10  ...                  1                     2
# 74         194           18  ...                  0                     1
# 81         206           39  ...                  1                     2
# 96         325           28  ...                  2                     3
# 97         327           18  ...                  0                     1
# 98         328           18  ...                  1                     1
# ...

# %%
cust20 = df2[df2['HS Customer']==20] #only ids that are 20

# %%
cust20
# Out:
#      Ticket ID  HS Customer  ... Agent interactions Customer interactions
# 2           44           20  ...                  1                     1
# 3           54           20  ...                  1                     1
# 16          97           20  ...                  1                     1
# 24         111           20  ...                  0                     6
# 121        446           20  ...                  1                     2
# 133        766           20  ...                  2                     3
# 143        781           20  ...                  3                     3
# 160        814           20  ...                  1                     1
# 167        824           20  ...                  0                     7
# 168        825           20  ...                  2                     2
# 184        848           20  ...                  1                     2
# 186        851           20  ...                  0                     1
# ...
