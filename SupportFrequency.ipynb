# %% [markdown]
# <a href="https://colab.research.google.com/github/nurfnick/Cantrell_Jackson/blob/master/SupportFrequency.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pa
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b0ec93f3-e2b3-4e0c-806e-08e808637db3" name="files[]" multiple disabled />
#      <output id="result-b0ec93f3-e2b3-4e0c-806e-08e808637db3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Support-Oct18-Sept19.csv to Support-Oct18-Sept19.csv

# %%
import io
df2 = pa.read_csv(io.BytesIO(uploaded['Support-Oct18-Sept19.csv']))# Dataset is now stored in a Pandas Dataframe

# %%
df2
# Out:
#      Ticket ID  HS Customer  ... Agent interactions Customer interactions
# 0           35           18  ...                  1                     1
# 1           36           19  ...                  2                     1
# 2           44           20  ...                  1                     1
# 3           54           20  ...                  1                     1
# 4           55           23  ...                  1                     1
# ..         ...          ...  ...                ...                   ...
# 279       1009           18  ...                  1                     1
# 280       1012           18  ...                  1                     3
# 281       1014           18  ...                  2                     3
# 282       1016           18  ...                  1                     2
# 283       1017           18  ...                  0                     3
#
# [284 rows x 13 columns]

# %%
df2[df2['HS Customer']==18] #only ids that are 18
# Out:
#      Ticket ID  HS Customer  ... Agent interactions Customer interactions
# 0           35           18  ...                  1                     1
# 5           65           18  ...                  1                     1
# 6           71           18  ...                  0                     1
# 7           73           18  ...                  1                     1
# 8           75           18  ...                  1                     1
# ..         ...          ...  ...                ...                   ...
# 279       1009           18  ...                  1                     1
# 280       1012           18  ...                  1                     3
# 281       1014           18  ...                  2                     3
# 282       1016           18  ...                  1                     2
# 283       1017           18  ...                  0                     3
#
# [121 rows x 13 columns]
